# %%
#Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# Pre-Modeling Tasks
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# Modeling
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# Evaluation the model  
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score ,auc ,f1_score ,roc_curve
from sklearn.metrics import precision_score, recall_score

# %%
df = pd.read_csv("data.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
# counting values of variables in 'diagnosis'
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df.shape
# Out:
# (569, 33)

# %%
# describing the dataset

df.describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# texture_se               569.0  1.216853e+00  5.516484e-01     0.360200
# perimeter_se             569.0  2.866059e+00  2.021855e+00     0.757000
# area_se                  569.0  4.033708e+01  4.549101e+01     6.802000
# smoothness_se            569.0  7.040979e-03  3.002518e-03     0.001713
# compactness_se           569.0  2.547814e-02  1.790818e-02     0.002252
# concavity_se             569.0  3.189372e-02  3.018606e-02     0.000000
# concave points_se        569.0  1.179614e-02  6.170285e-03     0.000000
# symmetry_se              569.0  2.054230e-02  8.266372e-03     0.007882
# fractal_dimension_se     569.0  3.794904e-03  2.646071e-03     0.000895
# radius_worst             569.0  1.626919e+01  4.833242e+00     7.930000
# texture_worst            569.0  2.567722e+01  6.146258e+00    12.020000
# perimeter_worst          569.0  1.072612e+02  3.360254e+01    50.410000
# area_worst               569.0  8.805831e+02  5.693570e+02   185.200000
# smoothness_worst         569.0  1.323686e-01  2.283243e-02     0.071170
# compactness_worst        569.0  2.542650e-01  1.573365e-01     0.027290
# concavity_worst          569.0  2.721885e-01  2.086243e-01     0.000000
# concave points_worst     569.0  1.146062e-01  6.573234e-02     0.000000
# symmetry_worst           569.0  2.900756e-01  6.186747e-02     0.156500
# fractal_dimension_worst  569.0  8.394582e-02  1.806127e-02     0.055040
# Unnamed: 32                0.0           NaN           NaN          NaN
#
#                                    25%            50%           75%  \
# id                       869218.000000  906024.000000  8.813129e+06
# radius_mean                  11.700000      13.370000  1.578000e+01
# texture_mean                 16.170000      18.840000  2.180000e+01
# perimeter_mean               75.170000      86.240000  1.041000e+02
# area_mean                   420.300000     551.100000  7.827000e+02
# smoothness_mean               0.086370       0.095870  1.053000e-01
# compactness_mean              0.064920       0.092630  1.304000e-01
# concavity_mean                0.029560       0.061540  1.307000e-01
# concave points_mean           0.020310       0.033500  7.400000e-02
# symmetry_mean                 0.161900       0.179200  1.957000e-01
# fractal_dimension_mean        0.057700       0.061540  6.612000e-02
# radius_se                     0.232400       0.324200  4.789000e-01
# texture_se                    0.833900       1.108000  1.474000e+00
# perimeter_se                  1.606000       2.287000  3.357000e+00
# area_se                      17.850000      24.530000  4.519000e+01
# smoothness_se                 0.005169       0.006380  8.146000e-03
# compactness_se                0.013080       0.020450  3.245000e-02
# concavity_se                  0.015090       0.025890  4.205000e-02
# concave points_se             0.007638       0.010930  1.471000e-02
# symmetry_se                   0.015160       0.018730  2.348000e-02
# fractal_dimension_se          0.002248       0.003187  4.558000e-03
# radius_worst                 13.010000      14.970000  1.879000e+01
# texture_worst                21.080000      25.410000  2.972000e+01
# perimeter_worst              84.110000      97.660000  1.254000e+02
# area_worst                  515.300000     686.500000  1.084000e+03
# smoothness_worst              0.116600       0.131300  1.460000e-01
# compactness_worst             0.147200       0.211900  3.391000e-01
# concavity_worst               0.114500       0.226700  3.829000e-01
# concave points_worst          0.064930       0.099930  1.614000e-01
# symmetry_worst                0.250400       0.282200  3.179000e-01
# fractal_dimension_worst       0.071460       0.080040  9.208000e-02
# Unnamed: 32                        NaN            NaN           NaN
#
#                                   max
# id                       9.113205e+08
# radius_mean              2.811000e+01
# texture_mean             3.928000e+01
# perimeter_mean           1.885000e+02
# area_mean                2.501000e+03
# smoothness_mean          1.634000e-01
# compactness_mean         3.454000e-01
# concavity_mean           4.268000e-01
# concave points_mean      2.012000e-01
# symmetry_mean            3.040000e-01
# fractal_dimension_mean   9.744000e-02
# radius_se                2.873000e+00
# texture_se               4.885000e+00
# perimeter_se             2.198000e+01
# area_se                  5.422000e+02
# smoothness_se            3.113000e-02
# compactness_se           1.354000e-01
# concavity_se             3.960000e-01
# concave points_se        5.279000e-02
# symmetry_se              7.895000e-02
# fractal_dimension_se     2.984000e-02
# radius_worst             3.604000e+01
# texture_worst            4.954000e+01
# perimeter_worst          2.512000e+02
# area_worst               4.254000e+03
# smoothness_worst         2.226000e-01
# compactness_worst        1.058000e+00
# concavity_worst          1.252000e+00
# concave points_worst     2.910000e-01
# symmetry_worst           6.638000e-01
# fractal_dimension_worst  2.075000e-01
# Unnamed: 32                       NaN

# %%
#Checking for missing values
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
#droping feature
df.drop(['Unnamed: 32','id'],axis=1,inplace=True)

# %%
#Encoding categorical data
LEncoder = LabelEncoder()

df['diagnosis'] = LEncoder.fit_transform(df['diagnosis'])

# %%
# independent variables
x = df.drop('diagnosis',axis=1)
#dependent variables
y = df.diagnosis

# %%
#Splitting the dataset
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
print ('Number of training samples input is', x_train.shape)
print ('Number of testing samples input is', x_test.shape)
print ('Number of training samples output is', y_train.shape)
print ('Number of testing samples output is', y_test.shape)
# Out:
# Number of training samples input is (455, 30)
# Number of testing samples input is (114, 30)
# Number of training samples output is (455,)
# Number of testing samples output is (114,)

# %%
#Feature Scaling
min_max_scaler = preprocessing.MinMaxScaler()
x_scale = min_max_scaler.fit_transform(x)

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
#creating model
classifier = Sequential()

# %%
#compiling the ANN
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
#first hidden layer
classifier.add(Dense(units=9,kernel_initializer='he_uniform',activation='relu',input_dim=30))
#second hidden layer
classifier.add(Dense(units=9,kernel_initializer='he_uniform',activation='relu'))
# last layer or output layer
classifier.add(Dense(units=1,kernel_initializer='glorot_uniform',activation='sigmoid'))

# %%
#taking summary of layers
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 9)                 279
# _________________________________________________________________
# dense_7 (Dense)              (None, 9)                 90
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 10
# =================================================================
# Total params: 379
# Trainable params: 379
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compiling the ANN
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
#fitting the ANN to the training set
model = classifier.fit(x_train,y_train,batch_size=100,epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4660 - accuracy: 0.6440
# Epoch 2/100
# 5/5 [==============================] - 0s 0s/step - loss: 1.3279 - accuracy: 0.6462
# Epoch 3/100
# 5/5 [==============================] - 0s 1ms/step - loss: 1.1999 - accuracy: 0.6593
# Epoch 4/100
# 5/5 [==============================] - 0s 2ms/step - loss: 1.0802 - accuracy: 0.6637
# Epoch 5/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.9637 - accuracy: 0.6769
# Epoch 6/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8528 - accuracy: 0.6879
# Epoch 7/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7450 - accuracy: 0.7055
# Epoch 8/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6541 - accuracy: 0.7275
# Epoch 9/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5715 - accuracy: 0.7648
# Epoch 10/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5020 - accuracy: 0.7802
# Epoch 11/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4426 - accuracy: 0.8110
# Epoch 12/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3926 - accuracy: 0.8286
# Epoch 13/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3520 - accuracy: 0.8527
# Epoch 14/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3199 - accuracy: 0.8637
# Epoch 15/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2939 - accuracy: 0.8747
# Epoch 16/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2729 - accuracy: 0.8923
# Epoch 17/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2551 - accuracy: 0.9033
# Epoch 18/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2409 - accuracy: 0.9143
# Epoch 19/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2283 - accuracy: 0.9275
# Epoch 20/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2169 - accuracy: 0.9253
# Epoch 21/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2077 - accuracy: 0.9231
# Epoch 22/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.1991 - accuracy: 0.9253
# Epoch 23/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1912 - accuracy: 0.9319
# Epoch 24/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1842 - accuracy: 0.9319
# Epoch 25/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1779 - accuracy: 0.9341
# Epoch 26/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1720 - accuracy: 0.9385
# Epoch 27/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1666 - accuracy: 0.9429
# Epoch 28/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1616 - accuracy: 0.9429
# Epoch 29/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1571 - accuracy: 0.9429
# Epoch 30/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1529 - accuracy: 0.9473
# Epoch 31/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.1489 - accuracy: 0.9582
# Epoch 32/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1452 - accuracy: 0.9582
# Epoch 33/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1416 - accuracy: 0.9626
# Epoch 34/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.1384 - accuracy: 0.9626
# Epoch 35/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1351 - accuracy: 0.9626
# Epoch 36/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1323 - accuracy: 0.9626
# Epoch 37/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1295 - accuracy: 0.9626
# Epoch 38/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1268 - accuracy: 0.9648
# Epoch 39/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1243 - accuracy: 0.9648
# Epoch 40/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1219 - accuracy: 0.9670
# Epoch 41/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1195 - accuracy: 0.9670
# Epoch 42/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1173 - accuracy: 0.9670
# Epoch 43/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1152 - accuracy: 0.9670
# Epoch 44/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1133 - accuracy: 0.9670
# Epoch 45/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.1113 - accuracy: 0.9670
# Epoch 46/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1095 - accuracy: 0.9692
# Epoch 47/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1076 - accuracy: 0.9692
# Epoch 48/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1059 - accuracy: 0.9692
# Epoch 49/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1042 - accuracy: 0.9692
# Epoch 50/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.1026 - accuracy: 0.9714
# Epoch 51/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1012 - accuracy: 0.9714
# Epoch 52/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0996 - accuracy: 0.9758
# Epoch 53/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0982 - accuracy: 0.9780
# Epoch 54/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0967 - accuracy: 0.9780
# Epoch 55/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.0955 - accuracy: 0.9780
# Epoch 56/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0941 - accuracy: 0.9780
# Epoch 57/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0928 - accuracy: 0.9780
# Epoch 58/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0916 - accuracy: 0.9780
# Epoch 59/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0905 - accuracy: 0.9780
# Epoch 60/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0894 - accuracy: 0.9780
# Epoch 61/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0883 - accuracy: 0.9780
# Epoch 62/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0873 - accuracy: 0.9780
# Epoch 63/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.9780
# Epoch 64/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0853 - accuracy: 0.9802
# Epoch 65/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.0843 - accuracy: 0.9802
# Epoch 66/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0833 - accuracy: 0.9802
# Epoch 67/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 0.9802
# Epoch 68/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0816 - accuracy: 0.9802
# Epoch 69/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.0807 - accuracy: 0.9802
# Epoch 70/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.9802
# Epoch 71/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0790 - accuracy: 0.9802
# Epoch 72/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.0782 - accuracy: 0.9802
# Epoch 73/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0775 - accuracy: 0.9802
# Epoch 74/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.9802
# Epoch 75/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0760 - accuracy: 0.9802
# Epoch 76/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.0752 - accuracy: 0.9802
# Epoch 77/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0745 - accuracy: 0.9802
# Epoch 78/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 0.9802
# Epoch 79/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0732 - accuracy: 0.9802
# Epoch 80/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0725 - accuracy: 0.9802
# Epoch 81/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0719 - accuracy: 0.9802
# Epoch 82/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0713 - accuracy: 0.9802
# Epoch 83/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0707 - accuracy: 0.9802
# Epoch 84/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.0700 - accuracy: 0.9802
# Epoch 85/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0694 - accuracy: 0.9802
# Epoch 86/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0689 - accuracy: 0.9802
# Epoch 87/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0683 - accuracy: 0.9802
# Epoch 88/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.0677 - accuracy: 0.9802
# Epoch 89/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.0672 - accuracy: 0.9802
# Epoch 90/100
# 5/5 [==============================] - 0s 0s/step - loss: 0.0667 - accuracy: 0.9802
# Epoch 91/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 0.9802
# Epoch 92/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0656 - accuracy: 0.9802
# Epoch 93/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0651 - accuracy: 0.9802
# Epoch 94/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0647 - accuracy: 0.9824
# Epoch 95/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 0.9824
# Epoch 96/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0637 - accuracy: 0.9824
# Epoch 97/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0633 - accuracy: 0.9824
# Epoch 98/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0628 - accuracy: 0.9824
# Epoch 99/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0623 - accuracy: 0.9824
# Epoch 100/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0619 - accuracy: 0.9824

# %%
#now testing for Test data
y_pred = classifier.predict(x_test)

# %%
#converting values
y_pred = (y_pred>0.5)
print(y_pred)
# Out:
# [[False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]]

# %%
#Confusion Matrix

cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[70  1]
#  [ 1 42]]

# %%
# creating heatmap of comfussion matrix
plt.figure(figsize=[14,7])
sb.heatmap(cm,annot=True)
plt.show()

# %%
accuracy =accuracy_score(y_test, y_pred)
print('accuracy is:',accuracy)

precision =precision_score(y_test, y_pred)
print('precision is:',precision)

recall =recall_score(y_test, y_pred)
print('recall is:',recall)
# Out:
# accuracy is: 0.9824561403508771
# precision is: 0.9767441860465116
# recall is: 0.9767441860465116

# %%
#Classification Report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        71
#            1       0.98      0.98      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
#Visualize Data History
print(model.history.keys())

# summarize history for accuracy
plt.plot(model.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
# summarize history for loss
plt.plot(model.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
def plot_roc_curve(fpr,tpr):
    plt.plot(fpr,tpr,color='orange' ,label='roc')
    plt.plot([0,1],[0,1],color='darkblue',linestyle='--')
    plt.xlabel('false positive rate')
    plt.ylabel('true positive rate')
    plt.title('reciver operating characteristic (roc) curve')
    plt.legend()
    plt.show()

# %%
preds = classifier.predict(x_test)

auc=roc_auc_score(y_test,preds)
print('AUC:%0.2f'%auc)
# Out:
# AUC:1.00

# %%
fpr,tpr,thresholds=roc_curve(y_test,preds)
plot_roc_curve(fpr,tpr)

# %%
#Area Under Curve
roc_auc_score(y_test, preds)
# Out:
# 0.9954143465443825
